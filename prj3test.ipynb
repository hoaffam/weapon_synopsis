# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content/drive/.shortcut-targets-by-id/1-5G4ZMsBsjvVKChCQndZmN4q97dy_tbF/project3weapon_synopsis

# %%
# %cd /content/drive/MyDrive/project3weapon_synopsis
# Out:
# /content/drive/.shortcut-targets-by-id/1-5G4ZMsBsjvVKChCQndZmN4q97dy_tbF/project3weapon_synopsis

# %%
# %cd ..
# Out:
# /content/drive

# %%
# %cd /content/drive/MyDrive/github_repos
# Out:
# /content/drive/MyDrive/github_repos

# %%
from getpass import getpass
user = getpass('Username: ') # Nhập username trên Github
password = getpass('Password: ') # Nhập password

# !git clone https://github.com/hoaffam/weapon_synopsis.git
# Out:
# Username: ··········
# Password: ··········
# Cloning into 'weapon_synopsis'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), 596 bytes | 29.00 KiB/s, done.

# %%
# !git add project3weapon_synopsis
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git init
# Out:
# /content/drive/.git: Operation not supported

# %% [markdown]
# # **YOLO V5**

# %%
# %cd /content/drive/MyDrive/project3weapon_sypnosis
# Out:
# /content/drive/MyDrive/project3weapon_sypnosis

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 14474, done.
# remote: Total 14474 (delta 0), reused 0 (delta 0), pack-reused 14474
# Receiving objects: 100% (14474/14474), 13.57 MiB | 6.47 MiB/s, done.
# Resolving deltas: 100% (9976/9976), done.
# Checking out files: 100% (146/146), done.

# %%
# %cd yolov5
# !pip install -r requirements.txt  # install

# %% [markdown]
# # **TEST**

# %%
# %cd /content/drive/MyDrive/project3weapon_synopsis/yolov5
# Out:
# /content/drive/.shortcut-targets-by-id/1-5G4ZMsBsjvVKChCQndZmN4q97dy_tbF/project3weapon_synopsis/yolov5

# %%
#exp6
# !python detect.py --weights /content/drive/MyDrive/project3weapon_synopsis/best_9_12_2022.pt --img 1080 --conf 0.5 --source /content/drive/MyDrive/project3weapon_synopsis/test_pistol.mp4
# Out:
# detect: weights=['/content/drive/MyDrive/project3weapon_synopsis/best_9_12_2022.pt'], source=/content/drive/MyDrive/project3weapon_synopsis/test_pistol.mp4, data=data/coco128.yaml, imgsz=[1080, 1080], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-32-g357cde9 Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7020913 parameters, 0 gradients
# WARNING ⚠️ --img-size [1080, 1080] must be multiple of max stride 32, updating to [1088, 1088]
# video 1/1 (1/1032) /content/drive/MyDrive/project3weapon_synopsis/test_pistol.mp4: 640x1088 2 persons, 18.8ms
# ...

# %%
#Test video quay vũ khí lần 1 (Tú quay và gửi)
# !python detect.py --weights /content/drive/MyDrive/project3weapon_synopsis/best_9_12_2022.pt --img 1080 --conf 0.5 --source /content/drive/MyDrive/Video
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# video 2/7 (6304/7387) /content/drive/.shortcut-targets-by-id/1-h9gbu1HM_MG1bUmeRXNcUUosevkMJ_8/Video/IMG_6359.MOV: 640x1088 1 pistol, 3 persons, 18.8ms
# video 2/7 (6305/7387) /content/drive/.shortcut-targets-by-id/1-h9gbu1HM_MG1bUmeRXNcUUosevkMJ_8/Video/IMG_6359.MOV: 640x1088 3 persons, 19.2ms
# video 2/7 (6306/7387) /content/drive/.shortcut-targets-by-id/1-h9gbu1HM_MG1bUmeRXNcUUosevkMJ_8/Video/IMG_6359.MOV: 640x1088 1 pistol, 4 persons, 18.8ms
# video 2/7 (6307/7387) /content/drive/.shortcut-targets-by-id/1-h9gbu1HM_MG1bUmeRXNcUUosevkMJ_8/Video/IMG_6359.MOV: 640x1088 1 pistol, 1 rifle, 4 persons, 18.8ms
# video 2/7 (6308/7387) /content/drive/.shortcut-targets-by-id/1-h9gbu1HM_MG1bUmeRXNcUUosevkMJ_8/Video/IMG_6359.MOV: 640x1088 1 pistol, 3 persons, 18.8ms
# video 2/7 (6309/7387) /content/drive/.shortcut-targets-by-id/1-h9gbu1HM_MG1bUmeRXNcUUosevkMJ_8/Video/IMG_6359.MOV: 640x1088 1 pistol, 4 persons, 18.8ms
# ...

# %%
#exp 8
# !python detect_synopsis.py --weights /content/drive/MyDrive/project3weapon_synopsis/best_9_12_2022.pt --img 1080 --conf 0.5 --source /content/drive/MyDrive/project3weapon_synopsis/test_pistol.mp4 --classes 0 3
# Out:
# detect_synopsis: weights=['/content/drive/MyDrive/project3weapon_synopsis/best_9_12_2022.pt'], source=/content/drive/MyDrive/project3weapon_synopsis/test_pistol.mp4, data=data/coco128.yaml, imgsz=[1080, 1080], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=[0, 3], agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-32-g357cde9 Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7020913 parameters, 0 gradients
# WARNING ⚠️ --img-size [1080, 1080] must be multiple of max stride 32, updating to [1088, 1088]
# video 1/1 (1/1032) /content/drive/.shortcut-targets-by-id/1-5G4ZMsBsjvVKChCQndZmN4q97dy_tbF/project3weapon_synopsis/test_pistol.mp4: 640x1088 2 persons, 19.3ms
# ...
